# %%
# !pip install pandas yfinance requests

# %%
import pandas as pd
import requests
import yfinance as yf

# %%
import yfinance as yf

jpm = yf.Ticker("JPM")

# %%
jpm.financials
# Out:
#                                                       2025-12-31  \
# Tax Effect Of Unusual Items                         2.205856e+08
# Tax Rate For Calcs                                  2.141610e-01
# Total Unusual Items                                 1.030000e+09
# Total Unusual Items Excluding Goodwill              1.030000e+09
# Net Income From Continuing Operation Net Minori...  5.704800e+10
# Reconciled Depreciation                             8.821000e+09
# Net Interest Income                                 9.544300e+10
# Interest Expense                                    9.789800e+10
# Interest Income                                     1.933410e+11
# Normalized Income                                   5.623859e+10
# Net Income From Continuing And Discontinued Ope...  5.704800e+10
# Diluted Average Shares                              2.781500e+09
# Basic Average Shares                                2.776500e+09
# ...

# %%
jpm.balance_sheet
# Out:
#                                                 2025-12-31    2024-12-31  \
# Treasury Shares Number                        1.408661e+09  1.307313e+09
# Preferred Shares Number                       3.918500e+08  3.918500e+08
# Ordinary Shares Number                        2.696273e+09  2.797620e+09
# Share Issued                                  4.104934e+09  4.104934e+09
# Net Debt                                      1.566440e+11           NaN
# Total Debt                                    4.999820e+11  4.543110e+11
# Tangible Book Value                           2.779350e+11  2.601480e+11
# Invested Capital                              8.423750e+11  7.790190e+11
# Net Tangible Assets                           2.979800e+11  2.801980e+11
# Common Stock Equity                           3.423930e+11  3.247080e+11
# Preferred Stock Equity                        2.004500e+10  2.005000e+10
# Total Capitalization                          7.964080e+11  7.461760e+11
# ...

# %%
jpm.cashflow
# Out:
#                                                   2025-12-31    2024-12-31  \
# Free Cash Flow                                 -1.477820e+11 -4.201200e+10
# Repurchase Of Capital Stock                    -3.459100e+10 -2.868000e+10
# Repayment Of Debt                              -1.081000e+11 -9.660500e+10
# Issuance Of Debt                                1.207610e+11  1.099150e+11
# Issuance Of Capital Stock                       3.000000e+09  2.500000e+09
# Interest Paid Supplemental Data                 9.643600e+10  9.964200e+10
# Income Tax Paid Supplemental Data               5.309000e+09  1.171500e+10
# End Cash Position                               3.433380e+11  4.693170e+11
# Beginning Cash Position                         4.693170e+11  6.241510e+11
# Effect Of Exchange Rate Changes                 1.783500e+10 -1.286600e+10
# Changes In Cash                                -1.438140e+11 -1.419680e+11
# ...

# %%
jpm.info
# Out:
# {'address1': '270 Park Avenue',
#  'city': 'New York',
#  'state': 'NY',
#  'zip': '10017',
#  'country': 'United States',
#  'phone': '212 270 6000',
#  'website': 'https://www.jpmorganchase.com',
#  'industry': 'Banks - Diversified',
#  'industryKey': 'banks-diversified',
#  'industryDisp': 'Banks - Diversified',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
# ...

# %%
history = jpm.history(period="5y")
history.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-06-07 00:00:00-04:00  147.177617  147.265752  145.538392  145.996674
# 2021-06-08 00:00:00-04:00  144.965549  146.084794  143.793414  145.415009
# 2021-06-09 00:00:00-04:00  144.657079  144.727585  143.017855  143.599518
# 2021-06-10 00:00:00-04:00  144.850943  145.626493  141.281663  141.360977
# 2021-06-11 00:00:00-04:00  141.387435  142.066042  140.180054  141.264053
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-06-07 00:00:00-04:00   7267200        0.0           0.0
# 2021-06-08 00:00:00-04:00  10370700        0.0           0.0
# 2021-06-09 00:00:00-04:00  12377400        0.0           0.0
# 2021-06-10 00:00:00-04:00  12119400        0.0           0.0
# 2021-06-11 00:00:00-04:00  13683800        0.0           0.0

# %%
import yfinance as yf

banks = ["JPM", "BAC", "WFC", "GS", "MS"]

for ticker in banks:
    company = yf.Ticker(ticker)
    print(f"\n{ticker}")
    print(company.financials.head())
# Out:
# JPM
#                                                       2025-12-31  \
# Tax Effect Of Unusual Items                         2.205856e+08
# Tax Rate For Calcs                                  2.141610e-01
# Total Unusual Items                                 1.030000e+09
# Total Unusual Items Excluding Goodwill              1.030000e+09
# Net Income From Continuing Operation Net Minori...  5.704800e+10
#
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                         1.294404e+09
# Tax Rate For Calcs                                  2.212280e-01
# Total Unusual Items                                 5.851000e+09
# Total Unusual Items Excluding Goodwill              5.851000e+09
# Net Income From Continuing Operation Net Minori...  5.847100e+10
#
#                                                       2023-12-31    2022-12-31
# Tax Effect Of Unusual Items                        -4.472720e+08  1.192320e+08
# ...

# %%
jpm = yf.Ticker("JPM")

jpm.financials.index
# Out:
# Index(['Tax Effect Of Unusual Items', 'Tax Rate For Calcs',
#        'Total Unusual Items', 'Total Unusual Items Excluding Goodwill',
#        'Net Income From Continuing Operation Net Minority Interest',
#        'Reconciled Depreciation', 'Net Interest Income', 'Interest Expense',
#        'Interest Income', 'Normalized Income',
#        'Net Income From Continuing And Discontinued Operation',
#        'Diluted Average Shares', 'Basic Average Shares', 'Diluted EPS',
#        'Basic EPS', 'Diluted NI Availto Com Stockholders',
#        'Net Income Common Stockholders', 'Otherunder Preferred Stock Dividend',
#        'Preferred Stock Dividends', 'Net Income',
#        'Net Income Including Noncontrolling Interests',
#        'Net Income Continuous Operations', 'Tax Provision', 'Pretax Income',
#        'Special Income Charges', 'Other Special Charges',
#        'Restructuring And Mergern Acquisition', 'Gain On Sale Of Security',
# ...

# %%
jpm.financials.loc["Total Revenue"]
# Out:
# 2025-12-31    1.818470e+11
# 2024-12-31    1.694390e+11
# 2023-12-31    1.549520e+11
# 2022-12-31    1.277270e+11
# Name: Total Revenue, dtype: float64

# %%
jpm.financials.loc["Net Income"]
# Out:
# 2025-12-31    5.704800e+10
# 2024-12-31    5.847100e+10
# 2023-12-31    4.955200e+10
# 2022-12-31    3.767600e+10
# Name: Net Income, dtype: float64

# %%
jpm.balance_sheet.index
# Out:
# Index(['Treasury Shares Number', 'Preferred Shares Number',
#        'Ordinary Shares Number', 'Share Issued', 'Net Debt', 'Total Debt',
#        'Tangible Book Value', 'Invested Capital', 'Net Tangible Assets',
#        'Common Stock Equity', 'Preferred Stock Equity', 'Total Capitalization',
#        'Total Equity Gross Minority Interest', 'Stockholders Equity',
#        'Gains Losses Not Affecting Retained Earnings',
#        'Other Equity Adjustments', 'Treasury Stock', 'Retained Earnings',
#        'Additional Paid In Capital', 'Capital Stock', 'Common Stock',
#        'Preferred Stock', 'Total Liabilities Net Minority Interest',
#        'Long Term Debt And Capital Lease Obligation', 'Long Term Debt',
#        'Current Debt And Capital Lease Obligation', 'Current Debt',
#        'Other Current Borrowings', 'Payables And Accrued Expenses', 'Payables',
#        'Other Payable', 'Accounts Payable', 'Total Assets',
#        'Investments And Advances', 'Held To Maturity Securities',
# ...

# %%
jpm.financials.index
# Out:
# Index(['Tax Effect Of Unusual Items', 'Tax Rate For Calcs',
#        'Total Unusual Items', 'Total Unusual Items Excluding Goodwill',
#        'Net Income From Continuing Operation Net Minority Interest',
#        'Reconciled Depreciation', 'Net Interest Income', 'Interest Expense',
#        'Interest Income', 'Normalized Income',
#        'Net Income From Continuing And Discontinued Operation',
#        'Diluted Average Shares', 'Basic Average Shares', 'Diluted EPS',
#        'Basic EPS', 'Diluted NI Availto Com Stockholders',
#        'Net Income Common Stockholders', 'Otherunder Preferred Stock Dividend',
#        'Preferred Stock Dividends', 'Net Income',
#        'Net Income Including Noncontrolling Interests',
#        'Net Income Continuous Operations', 'Tax Provision', 'Pretax Income',
#        'Special Income Charges', 'Other Special Charges',
#        'Restructuring And Mergern Acquisition', 'Gain On Sale Of Security',
# ...

# %%
jpm.financials.loc["Total Revenue"]
# Out:
# 2025-12-31    1.818470e+11
# 2024-12-31    1.694390e+11
# 2023-12-31    1.549520e+11
# 2022-12-31    1.277270e+11
# Name: Total Revenue, dtype: float64

# %%
jpm.financials.loc["Net Income"]
# Out:
# 2025-12-31    5.704800e+10
# 2024-12-31    5.847100e+10
# 2023-12-31    4.955200e+10
# 2022-12-31    3.767600e+10
# Name: Net Income, dtype: float64

# %%
jpm.balance_sheet.index
# Out:
# Index(['Treasury Shares Number', 'Preferred Shares Number',
#        'Ordinary Shares Number', 'Share Issued', 'Net Debt', 'Total Debt',
#        'Tangible Book Value', 'Invested Capital', 'Net Tangible Assets',
#        'Common Stock Equity', 'Preferred Stock Equity', 'Total Capitalization',
#        'Total Equity Gross Minority Interest', 'Stockholders Equity',
#        'Gains Losses Not Affecting Retained Earnings',
#        'Other Equity Adjustments', 'Treasury Stock', 'Retained Earnings',
#        'Additional Paid In Capital', 'Capital Stock', 'Common Stock',
#        'Preferred Stock', 'Total Liabilities Net Minority Interest',
#        'Long Term Debt And Capital Lease Obligation', 'Long Term Debt',
#        'Current Debt And Capital Lease Obligation', 'Current Debt',
#        'Other Current Borrowings', 'Payables And Accrued Expenses', 'Payables',
#        'Other Payable', 'Accounts Payable', 'Total Assets',
#        'Investments And Advances', 'Held To Maturity Securities',
# ...

# %%
jpm.balance_sheet.loc["Total Assets"]
# Out:
# 2025-12-31    4.424900e+12
# 2024-12-31    4.002814e+12
# 2023-12-31    3.875393e+12
# 2022-12-31    3.665743e+12
# Name: Total Assets, dtype: float64

# %%
jpm.balance_sheet.loc["Stockholders Equity"]
# Out:
# 2025-12-31    3.624380e+11
# 2024-12-31    3.447580e+11
# 2023-12-31    3.278780e+11
# 2022-12-31    2.923320e+11
# Name: Stockholders Equity, dtype: float64

# %%
revenue = jpm.financials.loc["Total Revenue"].iloc[0]

net_income = jpm.financials.loc["Net Income"].iloc[0]

assets = jpm.balance_sheet.loc["Total Assets"].iloc[0]

equity = jpm.balance_sheet.loc["Stockholders Equity"].iloc[0]

# %%
print(revenue)
print(net_income)
print(assets)
print(equity)
# Out:
# 181847000000.0
# 57048000000.0
# 4424900000000.0
# 362438000000.0

# %%
roe = net_income / equity

print(roe)
# Out:
# 0.1574007140531622

# %%
pd.options.display.float_format = '{:,.0f}'.format

df
# Out:
#   Company         Revenue     Net Income            Assets          Equity  \
# 0     JPM 181,847,000,000 57,048,000,000 4,424,900,000,000 362,438,000,000
#
#    ROE
# 0    0

# %%
import pandas as pd

df = pd.DataFrame({
    "Company": ["JPM"],
    "Revenue": [revenue],
    "Net Income": [net_income],
    "Assets": [assets],
    "Equity": [equity],
    "ROE": [roe]
})

df
# Out:
#   Company         Revenue     Net Income            Assets          Equity  \
# 0     JPM 181,847,000,000 57,048,000,000 4,424,900,000,000 362,438,000,000
#
#    ROE
# 0    0

# %%
df_display = df.copy()

df_display["Revenue"] = df_display["Revenue"].map('{:,.0f}'.format)
df_display["Net Income"] = df_display["Net Income"].map('{:,.0f}'.format)
df_display["Assets"] = df_display["Assets"].map('{:,.0f}'.format)
df_display["Equity"] = df_display["Equity"].map('{:,.0f}'.format)
df_display["ROE"] = df_display["ROE"].map('{:.2%}'.format)

df_display
# Out:
#   Company          Revenue      Net Income             Assets  \
# 0     JPM  181,847,000,000  57,048,000,000  4,424,900,000,000
#
#             Equity     ROE
# 0  362,438,000,000  15.74%

# %%
def get_bank_data(ticker):

    company = yf.Ticker(ticker)

    revenue = company.financials.loc["Total Revenue"].iloc[0]

    net_income = company.financials.loc["Net Income"].iloc[0]

    assets = company.balance_sheet.loc["Total Assets"].iloc[0]

    equity = company.balance_sheet.loc["Stockholders Equity"].iloc[0]

    roe = net_income / equity

    return {
        "Company": ticker,
        "Revenue": revenue,
        "Net Income": net_income,
        "Assets": assets,
        "Equity": equity,
        "ROE": roe
    }

# %%
jpm_data = get_bank_data("JPM")

jpm_data
# Out:
# {'Company': 'JPM',
#  'Revenue': np.float64(181847000000.0),
#  'Net Income': np.float64(57048000000.0),
#  'Assets': np.float64(4424900000000.0),
#  'Equity': np.float64(362438000000.0),
#  'ROE': np.float64(0.1574007140531622)}

# %%
banks = ["JPM", "BAC", "WFC", "GS", "MS"]

data = []

for ticker in banks:
    data.append(get_bank_data(ticker))

df = pd.DataFrame(data)

df
# Out:
#   Company         Revenue     Net Income            Assets          Equity  \
# 0     JPM 181,847,000,000 57,048,000,000 4,424,900,000,000 362,438,000,000
# 1     BAC 113,097,000,000 30,509,000,000 3,411,738,000,000 303,243,000,000
# 2     WFC  83,699,000,000 21,338,000,000 2,148,631,000,000 181,117,000,000
# 3      GS  58,283,000,000 17,176,000,000 1,809,320,000,000 124,972,000,000
# 4      MS  65,966,000,000 16,861,000,000 1,420,270,000,000 111,632,000,000
#
#    ROE
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0

# %%
df["ROE"] = df["ROE"] * 100

df
# Out:
#   Company         Revenue     Net Income            Assets          Equity  \
# 0     JPM 181,847,000,000 57,048,000,000 4,424,900,000,000 362,438,000,000
# 1     BAC 113,097,000,000 30,509,000,000 3,411,738,000,000 303,243,000,000
# 2     WFC  83,699,000,000 21,338,000,000 2,148,631,000,000 181,117,000,000
# 3      GS  58,283,000,000 17,176,000,000 1,809,320,000,000 124,972,000,000
# 4      MS  65,966,000,000 16,861,000,000 1,420,270,000,000 111,632,000,000
#
#    ROE
# 0   16
# 1   10
# 2   12
# 3   14
# 4   15

# %%
df.sort_values("ROE", ascending=False)
# Out:
#   Company         Revenue     Net Income            Assets          Equity  \
# 0     JPM 181,847,000,000 57,048,000,000 4,424,900,000,000 362,438,000,000
# 4      MS  65,966,000,000 16,861,000,000 1,420,270,000,000 111,632,000,000
# 3      GS  58,283,000,000 17,176,000,000 1,809,320,000,000 124,972,000,000
# 2     WFC  83,699,000,000 21,338,000,000 2,148,631,000,000 181,117,000,000
# 1     BAC 113,097,000,000 30,509,000,000 3,411,738,000,000 303,243,000,000
#
#    ROE
# 0   16
# 4   15
# 3   14
# 2   12
# 1   10

# %%
def get_stock_return(ticker):

    stock = yf.Ticker(ticker)

    prices = stock.history(period="1y")

    start_price = prices["Close"].iloc[0]

    end_price = prices["Close"].iloc[-1]

    return ((end_price - start_price) / start_price) * 100

# %%
get_stock_return("JPM")
# Out:
# np.float64(20.99110326349858)

# %%
df["Stock Return"] = df["Company"].apply(get_stock_return)

df
# Out:
#   Company         Revenue     Net Income            Assets          Equity  \
# 0     JPM 181,847,000,000 57,048,000,000 4,424,900,000,000 362,438,000,000
# 1     BAC 113,097,000,000 30,509,000,000 3,411,738,000,000 303,243,000,000
# 2     WFC  83,699,000,000 21,338,000,000 2,148,631,000,000 181,117,000,000
# 3      GS  58,283,000,000 17,176,000,000 1,809,320,000,000 124,972,000,000
# 4      MS  65,966,000,000 16,861,000,000 1,420,270,000,000 111,632,000,000
#
#    ROE  Stock Return
# 0   16            21
# 1   10            25
# 2   12            11
# 3   14            84
# 4   15            71

# %%
df["Company"]
# Out:
# 0    JPM
# 1    BAC
# 2    WFC
# 3     GS
# 4     MS
# Name: Company, dtype: object

# %%
df["Company"].apply(get_stock_return)
# Out:
# 0   21
# 1   25
# 2   11
# 3   84
# 4   71
# Name: Company, dtype: float64

# %%
df.sort_values("Stock Return", ascending=False)
# Out:
#   Company         Revenue     Net Income            Assets          Equity  \
# 3      GS  58,283,000,000 17,176,000,000 1,809,320,000,000 124,972,000,000
# 4      MS  65,966,000,000 16,861,000,000 1,420,270,000,000 111,632,000,000
# 1     BAC 113,097,000,000 30,509,000,000 3,411,738,000,000 303,243,000,000
# 0     JPM 181,847,000,000 57,048,000,000 4,424,900,000,000 362,438,000,000
# 2     WFC  83,699,000,000 21,338,000,000 2,148,631,000,000 181,117,000,000
#
#    ROE  Stock Return
# 3   14            84
# 4   15            71
# 1   10            25
# 0   16            21
# 2   12            11

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.scatter(df["ROE"], df["Stock Return"])

for i, company in enumerate(df["Company"]):
    plt.annotate(company,
                 (df["ROE"].iloc[i],
                  df["Stock Return"].iloc[i]))

plt.xlabel("ROE (%)")
plt.ylabel("Stock Return (%)")
plt.title("ROE vs Stock Return")

plt.show()

# %%
df[["ROE", "Stock Return"]].corr()
# Out:
#               ROE  Stock Return
# ROE             1             0
# Stock Return    0             1

# %%
df.dtypes
# Out:
# Company          object
# Revenue         float64
# Net Income      float64
# Assets          float64
# Equity          float64
# ROE             float64
# Stock Return    float64
# dtype: object

# %%
pd.reset_option('display.float_format')

# %%
df[["ROE", "Stock Return"]].corr()
# Out:
#                    ROE  Stock Return
# ROE           1.000000      0.396146
# Stock Return  0.396146      1.000000

# %%
corr = df["ROE"].corr(df["Stock Return"])

print(corr)
# Out:
# 0.39614574260714897

# %%
df[["ROE", "Stock Return"]].corr()
# Out:
#                    ROE  Stock Return
# ROE           1.000000      0.396146
# Stock Return  0.396146      1.000000

# %%
def get_bank_data(ticker):

    company = yf.Ticker(ticker)

    revenue = company.financials.loc["Total Revenue"].iloc[0]
    previous_revenue = company.financials.loc["Total Revenue"].iloc[1]

    revenue_growth = ((revenue - previous_revenue) / previous_revenue) * 100

    net_income = company.financials.loc["Net Income"].iloc[0]

    assets = company.balance_sheet.loc["Total Assets"].iloc[0]

    equity = company.balance_sheet.loc["Stockholders Equity"].iloc[0]

    roe = (net_income / equity) * 100

    return {
        "Company": ticker,
        "Revenue": revenue,
        "Revenue Growth": revenue_growth,
        "Net Income": net_income,
        "Assets": assets,
        "Equity": equity,
        "ROE": roe
    }

# %%
banks = ["JPM", "BAC", "WFC", "GS", "MS"]

data = []

for ticker in banks:
    data.append(get_bank_data(ticker))

df = pd.DataFrame(data)

df
# Out:
#   Company       Revenue  Revenue Growth    Net Income        Assets  \
# 0     JPM  1.818470e+11        7.322989  5.704800e+10  4.424900e+12
# 1     BAC  1.130970e+11        6.840425  3.050900e+10  3.411738e+12
# 2     WFC  8.369900e+10        1.704822  2.133800e+10  2.148631e+12
# 3      GS  5.828300e+10        8.915757  1.717600e+10  1.809320e+12
# 4      MS  6.596600e+10       14.482567  1.686100e+10  1.420270e+12
#
#          Equity        ROE
# 0  3.624380e+11  15.740071
# 1  3.032430e+11  10.060908
# 2  1.811170e+11  11.781335
# 3  1.249720e+11  13.743879
# 4  1.116320e+11  15.104092

# %%
df["Stock Return"] = df["Company"].apply(get_stock_return)

df
# Out:
#   Company       Revenue  Revenue Growth    Net Income        Assets  \
# 0     JPM  1.818470e+11        7.322989  5.704800e+10  4.424900e+12
# 1     BAC  1.130970e+11        6.840425  3.050900e+10  3.411738e+12
# 2     WFC  8.369900e+10        1.704822  2.133800e+10  2.148631e+12
# 3      GS  5.828300e+10        8.915757  1.717600e+10  1.809320e+12
# 4      MS  6.596600e+10       14.482567  1.686100e+10  1.420270e+12
#
#          Equity        ROE  Stock Return
# 0  3.624380e+11  15.740071     20.991103
# 1  3.032430e+11  10.060908     24.804876
# 2  1.811170e+11  11.781335     11.363062
# 3  1.249720e+11  13.743879     83.964609
# 4  1.116320e+11  15.104092     71.136349

# %%
corr_growth = df["Revenue Growth"].corr(df["Stock Return"])

print(corr_growth)
# Out:
# 0.7570340504449217

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.scatter(df["Revenue Growth"], df["Stock Return"])

for i, company in enumerate(df["Company"]):
    plt.annotate(
        company,
        (
            df["Revenue Growth"].iloc[i],
            df["Stock Return"].iloc[i]
        )
    )

plt.xlabel("Revenue Growth (%)")
plt.ylabel("Stock Return (%)")
plt.title("Revenue Growth vs Stock Return")

plt.show()

# %%
df_display = df.copy()

df_display["Revenue"] = df_display["Revenue"].map('{:,.0f}'.format)
df_display["Net Income"] = df_display["Net Income"].map('{:,.0f}'.format)
df_display["Assets"] = df_display["Assets"].map('{:,.0f}'.format)
df_display["Equity"] = df_display["Equity"].map('{:,.0f}'.format)

df_display["Revenue Growth"] = df_display["Revenue Growth"].map('{:.2f}%'.format)
df_display["ROE"] = df_display["ROE"].map('{:.2f}%'.format)
df_display["Stock Return"] = df_display["Stock Return"].map('{:.2f}%'.format)

df_display
# Out:
#   Company          Revenue Revenue Growth      Net Income             Assets  \
# 0     JPM  181,847,000,000          7.32%  57,048,000,000  4,424,900,000,000
# 1     BAC  113,097,000,000          6.84%  30,509,000,000  3,411,738,000,000
# 2     WFC   83,699,000,000          1.70%  21,338,000,000  2,148,631,000,000
# 3      GS   58,283,000,000          8.92%  17,176,000,000  1,809,320,000,000
# 4      MS   65,966,000,000         14.48%  16,861,000,000  1,420,270,000,000
#
#             Equity     ROE Stock Return
# 0  362,438,000,000  15.74%       20.99%
# 1  303,243,000,000  10.06%       24.80%
# 2  181,117,000,000  11.78%       11.36%
# 3  124,972,000,000  13.74%       83.96%
# 4  111,632,000,000  15.10%       71.14%

# %%
df_billions = df.copy()

for col in ["Revenue", "Net Income", "Assets", "Equity"]:
    df_billions[col] = df_billions[col] / 1_000_000_000

df_billions
# Out:
#   Company  Revenue  Revenue Growth  Net Income    Assets   Equity        ROE  \
# 0     JPM  181.847        7.322989      57.048  4424.900  362.438  15.740071
# 1     BAC  113.097        6.840425      30.509  3411.738  303.243  10.060908
# 2     WFC   83.699        1.704822      21.338  2148.631  181.117  11.781335
# 3      GS   58.283        8.915757      17.176  1809.320  124.972  13.743879
# 4      MS   65.966       14.482567      16.861  1420.270  111.632  15.104092
#
#    Stock Return
# 0     20.991103
# 1     24.804876
# 2     11.363062
# 3     83.964609
# 4     71.136349
